# %% [markdown]
# ### Blackjack - Basic Strategy

# %% [markdown]
# This file contains the implementation of Basic strategy of Blackjack with and with Q-learning agent along with Rule Variations.

# %% [markdown]
# #### BlackJack - Basic strategy without Q-Learning

# %% [markdown]
# All the Neccessary packages are imported

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools
import random
import seaborn as sns
from matplotlib.patches import Patch
from mpl_toolkits.mplot3d import Axes3D
from collections import defaultdict
import matplotlib.colors as mcolors

# %% [markdown]
# Defines all the constants neccesary in the implementation for easy access of the data

# %%
# Define constants

# suits
SPADES = "spades"
HEARTS = "hearts"
DIAMONDS = "diamonds"
CLUBS = "clubs"
# values
TWO = "2"
THREE = "3"
FOUR = "4"
FIVE = "5"
SIX = "6"
SEVEN = "7"
EIGHT = "8"
NINE = "9"
TEN = "10"
JACK = "jack"
QUEEN = "queen"
KING = "king"
ACE = "ace"

# ace values
ACE_HIGH_VALUE = 11
ACE_LOW_VALUE = 1

# Rewards
DRAW_REWARD = 0
WIN_REWARD = 1
LOSE_REWARD = -1
DOUBLE_DOWN_WIN_REWARD = 2
DOUBLE_DOWN_LOSE_REWARD = -2
WIN_BLACKJACK_REWARD = 10
WIN_BLACKJACK_REWARD_6_TO_5 = 12
INVALID_ACTION_REWARD = -3
VALID_ACTION_REWARD = 3


# actions
HIT = "hit"
STAND = "stand"
DOUBLE_DOWN = "double_down"
SPLIT = "split"
ACTIONS = [HIT,STAND,DOUBLE_DOWN,SPLIT]
HARD_HAND = "hard"
SOFT_HAND = "soft"

# card counting categories
HIGH_CARDS = [TEN, JACK, QUEEN, KING, ACE]
LOW_CARDS = [TWO, THREE, FOUR, FIVE, SIX]
NEUTRAL_CARDS = [SEVEN, EIGHT, NINE]

# %% [markdown]
# This class `Blackjack (object)` defines the blackjack environment all the basic rules and actions

# %%
class Blackjack (object):
    def __init__ (self,random_seed=None) :
        if random_seed is not None:
            random.seed(random_seed)
        self.deck = self.create_deck()
        self.player_card = []
        self.dealer_card = []
        self.has_ace = False
        self.end_game = False
        self.reward = 0
        self.hand = HARD_HAND
        self.split_flag = False
        self.natural_flag = False
        self.newgame = self.reset()
    
    
    def create_deck(self) :
        suits = [SPADES,DIAMONDS,HEARTS,CLUBS]
        ranks = [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE]
        deck = list(itertools.product(ranks,suits))
        random.shuffle(deck)
        return deck
        
    def get_card(self) :
        top_card = self.deck.pop()
        if(len(top_card) == 0) :
            top_card = self.create_deck().pop()
        return top_card
        
    def calculate_card_value(self,dealer_card,cards):
        value = 0
        number_aces = 0 
        self.hand = HARD_HAND
        for card , suit in cards :
            if str(card).lower() in [JACK,QUEEN,KING] :
                 value+=10
            elif str(card).isnumeric() :
                value+=int(card)
            elif str(card).lower() in [ACE] : 
                number_aces +=1 
        if dealer_card :
            for i in range (number_aces):
                if (value + 11 ) > 21 :
                    value += ACE_LOW_VALUE
                else :
                    value+= ACE_HIGH_VALUE
        else :
            for i in range (number_aces):
                if (value + 11 ) > 21 :
                    value += ACE_LOW_VALUE
                    self.hand = HARD_HAND
                else :
                    value+= ACE_HIGH_VALUE
                    self.hand = SOFT_HAND
            
        
        return value
    
    def reset(self) :
        #Re-initialisation for starting new game or episode 
        self.deck = self.create_deck()
        self.player_card = [self.get_card(), self.get_card()]
        self.dealer_card = [self.get_card(), self.get_card()]
        self.hand = HARD_HAND
        self.has_ace = self.contains_ace(self.player_card)
        self.end_game = False
        self.split_flag = True if (len(self.player_card) == 2 and self.player_card[0][0] == self.player_card[1][0]) else False
        self.natural_flag = True if (len(self.player_card) == 2 and self.calculate_card_value(False,self.player_card) == 21) else False
        return self.state_status()

    def state_status(self):
        player_card_value = self.calculate_card_value(False,self.player_card)
        dealer_first_card = self.dealer_card[0][0]
        self.split_flag = True if (len(self.player_card) == 2 and self.player_card[0][0] == self.player_card[1][0]) else False
        self.natural_flag = True if (len(self.player_card) == 2 and self.calculate_card_value(False,self.player_card) == 21) else False
        return player_card_value,dealer_first_card,self.has_ace,self.hand,self.split_flag,self.natural_flag
    
    def contains_ace(self,player_card) : 
        for card , suit in player_card :
            if card.casefold() == ACE.casefold() :
                return True
        return False


    def step(self,rule_no_dd_hard_11,rule_6_to_5) :
        player_card_numbers = []
        dealer_card_numbers = []
        for p_card in self.player_card :
            player_card_numbers.append(p_card[0]) 
            
        for d_card in self.dealer_card :
            dealer_card_numbers.append(d_card[0]) 
            
        if len(player_card_numbers) == 2 and len(dealer_card_numbers) == 2 :
            state_status, self.reward, end_game = self.check_for_blackjack(rule_6_to_5)
            if end_game :
                return state_status,self.reward, end_game
            
            split_flag = self.choose_splitting_pairs(player_card_numbers,dealer_card_numbers[0])
            double_down_flag = self.choose_double_down(player_card_numbers,dealer_card_numbers[0],self.calculate_card_value(False,self.player_card),rule_no_dd_hard_11)

            if split_flag :
                self.split_pairs(dealer_card_numbers[0],rule_no_dd_hard_11)
            elif double_down_flag :
                action,double_down_action = self.double_down(self.player_card)
                self.general_rule(action,double_down_action)
            else :
                action = self.hit_or_stand(dealer_card_numbers[0],self.calculate_card_value(False,self.player_card))
                self.general_rule(action,None)
        else :
            action = self.hit_or_stand(dealer_card_numbers[0],self.calculate_card_value(False,self.player_card))
            self.general_rule(action,None)

        return self.state_status(),self.reward,self.end_game 
        
    def general_rule(self,action,double_down_action) :
        # Hit / Stand
        if action.lower() == HIT :
            self.player_card.append(self.get_card())
            player_card_value = self.calculate_card_value(False,self.player_card)
            if(player_card_value > 21) :
                #print("Player Lost / busted ")
                self.end_game = True
                self.reward = LOSE_REWARD
                return self.state_status(),self.reward,self.end_game
            else : 
                self.reward = 0
        elif action.lower() == STAND :
            #End of players turn, begin dealers turn
            self.end_game = True
            dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            while (dealer_card_value < 17 ) :
                self.dealer_card.append(self.get_card())
                dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            
            self.reward = self.winner_or_loser(double_down_action)     
        return self.state_status(),self.reward,self.end_game 
    
    
    def winner_or_loser(self,double_down_action) : 
        player_card_value = self.calculate_card_value(False,self.player_card)
        dealer_card_value = self.calculate_card_value(True,self.dealer_card)
        if double_down_action == DOUBLE_DOWN :
            if player_card_value  > 21 :
                return DOUBLE_DOWN_LOSE_REWARD #player busted
            elif dealer_card_value > 21 :
                return DOUBLE_DOWN_WIN_REWARD #Player wins dealer busted
            elif player_card_value > dealer_card_value :
                return DOUBLE_DOWN_WIN_REWARD # Player wins
            elif player_card_value < dealer_card_value : 
                return DOUBLE_DOWN_LOSE_REWARD #Player lost dealer won
            else : 
                return DRAW_REWARD #its draw
        else :
            if player_card_value  > 21 :
                return LOSE_REWARD #player busted
            elif dealer_card_value > 21 :
                return WIN_REWARD #Player wins dealer busted
            elif player_card_value > dealer_card_value :
                return WIN_REWARD # Player wins
            elif player_card_value < dealer_card_value : 
                return LOSE_REWARD #Player lost dealer won
            else : 
                return DRAW_REWARD #its draw
        
    def check_for_blackjack(self,rule_6_to_5) :
        player_card_numbers = []
        dealer_card_numbers = []
        for p_card in self.player_card :
            player_card_numbers.append(p_card[0]) 
            
        for d_card in self.dealer_card :
            dealer_card_numbers.append(d_card[0]) 
            
        self.end_game = False
        if len(player_card_numbers) == 2 and len(dealer_card_numbers) == 2 :
            player_card_value = self.calculate_card_value(False,self.player_card)
            dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            if player_card_value  == 21 and dealer_card_value == 21:
                self.end_game = True
                self.reward = DRAW_REWARD
            if player_card_value == 21 :
                self.end_game = True
                if rule_6_to_5 :
                    self.reward = WIN_BLACKJACK_REWARD_6_TO_5  #Rule variation Apply 6 to 5 rule for blackjack instead of 3 to 2
                else :
                    self.reward = WIN_BLACKJACK_REWARD
            
        return self.state_status(),self.reward,self.end_game         
    
    #when same numbers occur twice split
    def choose_splitting_pairs(self,player_card_numbers,dealer_face_up_card):
        split = False
        if len(player_card_numbers) == 2:
            if player_card_numbers[0] == player_card_numbers [1] :
                #always split
                if player_card_numbers[0] in [ACE,EIGHT] :
                    split = True
                
                #never split
                if player_card_numbers[0] in [FIVE,TEN,JACK,QUEEN,KING]:
                    split = False
                
                #split based on dealer up card
                #if dealer face up card is b/w 2-7 and player has 2s or 3s or 7s
                if (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in TWO) or (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in THREE) or (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in SEVEN):
                    split = True
                
                #if dealer face up card is b/w 5-6 and player has 4s
                if dealer_face_up_card in [FIVE,SIX] and player_card_numbers[0] in FOUR :
                    split = True
                
                #if dealer face up card is b/w 2-6 and player has 6s
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX] and player_card_numbers[0] in SIX :
                    split = True
                
                #if dealer face up card is b/w 2-6 and player has 6s
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,EIGHT,NINE] and player_card_numbers[0] in NINE :
                    split = True
            
        return split
    
    #conditions for double down
    def choose_double_down(self,player_card_numbers,dealer_face_up_card,player_card_value,rule_no_dd_hard_11) :
        double_down = False
       
        if len(player_card_numbers) == 2 :
            #if hard hand
            if self.hand == HARD_HAND :
                #gets 11 always double down
                if player_card_value == 11 :
                    if rule_no_dd_hard_11 :
                        double_down = False  #Rule variation do not double down when hard 11
                    else :
                        double_down = True
                #if dealer face up card is b/w 2-9 and player has hard 10
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT,NINE] and player_card_value == 10 :
                    double_down = True
                #if dealer face up card is b/w 3-6 and player has hard 9
                if dealer_face_up_card in [THREE,FOUR,FIVE,SIX] and player_card_value == 8 :
                    double_down = True
            
            if self.hand == SOFT_HAND :
                #if dealer face up card is b/w 3-6 and player has soft 13 - 18
                if player_card_value in range (13,19) and dealer_face_up_card in [THREE,FOUR,FIVE,SIX]:
                    double_down = True
                #if dealer face up card is b/w 6 and player has soft 19
                if player_card_value == 19 and dealer_face_up_card in [SIX]:
                    double_down = True
                
        return double_down
                       
    def hit_or_stand(self,dealer_face_up_card,player_card_value) :
        action = ''
        if self.hand == HARD_HAND :
            #if player has hard <=8
            if player_card_value <= 11 :
                action = HIT
                
            #if dealer face up card is 2-3 or 7-A and player has hard 12 else stand
            if player_card_value == 12 :
                if dealer_face_up_card in [TWO,THREE,SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                else : 
                    action = STAND 
        
            #if dealer face up card is 7-A and player has hard 13-16 else stand
            if player_card_value in range (13,17) :
                if dealer_face_up_card in [SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                else : 
                    action = STAND
                
            #if  player has hard >= 17 else stand
            if player_card_value >= 17 :
                action = STAND
        
        if self.hand == SOFT_HAND :
            
            #if dealer face up card is 2-4 or 7-A and player has soft 13-14
            if player_card_value <= 17 :
                action = HIT

            #if dealer face up card is 9-A and player has soft 18 else stand dealers face up card is 2 or 7,8
            if player_card_value == 18 :
                if dealer_face_up_card in [NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                elif dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT] : 
                    action = STAND
                
            #if dealer face up card is not 6 and player has soft 19
            if player_card_value >= 19 :
                action = STAND
        
        return action
    
    def split_pairs(self,dealer_face_up_card,rule_no_dd_hard_11):
        rewards = []
        player_new_card_1 = self.get_card()
        player_new_card_2 = self.get_card()
        player_hand_1 = [self.player_card[0], player_new_card_1]
        player_hand_2 = [self.player_card[1], player_new_card_2]
        player_hands = [player_hand_1, player_hand_2]
        self.player_card.append(player_new_card_1)
        self.player_card.append(player_new_card_2)
       
        for hand in player_hands:
            hand_card_numbers = []
            self.player_card = hand  # Set current hand to be played
            self.has_ace = self.contains_ace(hand)
            
            for p_card in hand :
                hand_card_numbers.append(p_card[0]) 
            
            double_down_flag = self.choose_double_down(hand_card_numbers,dealer_face_up_card,self.calculate_card_value(False,hand),rule_no_dd_hard_11)
            if double_down_flag :
                action,double_down_action = self.double_down(hand)
                state_status,self.reward,self.end_game = self.general_rule(action,double_down_action)
                rewards.append(self.reward)
            else : 
                action = self.hit_or_stand(dealer_face_up_card,self.calculate_card_value(False,hand))
                state_status,self.reward,self.end_game = self.general_rule(action,None)
                rewards.append(self.reward)
        
        # Determine final rewards based on the outcome of both hands
        if all(reward > 0 for reward in rewards):
            # Both hands win
            self.reward = sum(rewards)  # Add rewards for both winning hands
        elif all(reward < 0 for reward in rewards):
            # Both hands lose
            self.reward = sum(rewards)  # Sum of negative rewards is negative
        else:
            # One hand wins and one hand loses
            self.reward = sum(rewards)  # Net reward
        
        self.reward+=VALID_ACTION_REWARD
        return self.state_status(),self.reward,self.end_game 
        
    def double_down(self,hand) :
        hand.append(self.get_card())
        self.end_game = True
        action = STAND
        return action,DOUBLE_DOWN

# %% [markdown]
# Testing

# %%
def test_blackjack_bs(num_episodes,rule_no_dd_hard_11,rule_6_to_5):
    env = Blackjack()
    wins = 0
    losses = 0
    draws = 0
    pos_rewards = []
    neg_rewards = []
    neu_rewards = []
    average_reward = 0.0
    for _ in range(num_episodes):
        env.reset()
        done = False

        while not done:
            _, reward, done = env.step(rule_no_dd_hard_11,rule_6_to_5)
       
        if reward in [WIN_REWARD, WIN_BLACKJACK_REWARD, DOUBLE_DOWN_WIN_REWARD]:
            pos_rewards.append(reward)
            wins += 1
        elif reward in [LOSE_REWARD ,DOUBLE_DOWN_LOSE_REWARD]:
            neg_rewards.append(reward)
            losses += 1
        else:
            neu_rewards.append(reward)
            draws += 1
        
    win_rate = wins / num_episodes * 100
    loss_rate = losses / num_episodes * 100
    draw_rate = draws / num_episodes * 100
   
    
    print(f"Average  win reward : {sum(pos_rewards)/wins:.2f} , average loss reward : {sum(neg_rewards)/losses:.2f} , average draw reward: {sum(neu_rewards)/draws:.2f}")
    print(f"Wins: {wins} , win percentage: {win_rate:.2f}%")
    print(f"Losses: {losses} , loss percentage: {loss_rate:.2f}%")
    print(f"Draws: {draws} , draw percentage: {draw_rate:.2f}%")

# %%
test_blackjack_bs(100000,False,False)
# Out:
# Average  win reward : 2.14 , average loss reward : -1.09 , average draw reward: 0.50
# Wins: 43633 , win percentage: 43.63%
# Losses: 46823 , loss percentage: 46.82%
# Draws: 9544 , draw percentage: 9.54%

# %% [markdown]
# #### BlackJack - Basic strategy with Q-Learning

# %%
class Blackjack_Q (object):
    def __init__ (self) :
        self.deck = self.create_deck()
        self.player_card = []
        self.dealer_card = []
        self.has_ace = False
        self.end_game = False
        self.reward = 0
        self.hand = HARD_HAND
        self.split_flag = False
        self.natural_flag = False
        self.newgame = self.reset()
    
    
    def create_deck(self) :
        suits = [SPADES,DIAMONDS,HEARTS,CLUBS]
        ranks = [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE]
        deck = list(itertools.product(ranks,suits))
        random.shuffle(deck)
        return deck
        
    def get_card(self) :
        top_card = self.deck.pop()
        if(len(top_card) == 0) :
            top_card = self.create_deck().pop()
        return top_card
        
    def calculate_card_value(self,dealer_card,cards):
        value = 0
        number_aces = 0 
        self.hand = HARD_HAND
        for card , suit in cards :
            if str(card).lower() in [JACK,QUEEN,KING] :
                 value+=10
            elif str(card).isnumeric() :
                value+=int(card)
            elif str(card).lower() in [ACE] : 
                number_aces +=1 
        if dealer_card :
            for i in range (number_aces):
                if (value + 11 ) > 21 :
                    value += ACE_LOW_VALUE
                else :
                    value+= ACE_HIGH_VALUE
        else :
            for i in range (number_aces):
                if (value + 11 ) > 21 :
                    value += ACE_LOW_VALUE
                    self.hand = HARD_HAND
                else :
                    value+= ACE_HIGH_VALUE
                    self.hand = SOFT_HAND
            
        
        return value
    
    def reset(self) :
        #Re-initialisation for starting new game or episode 
        self.deck = self.create_deck()
        self.player_card = [self.get_card(), self.get_card()]
        self.dealer_card = [self.get_card(), self.get_card()]
        self.hand = HARD_HAND
        self.has_ace = self.contains_ace(self.player_card)
        self.end_game = False
        self.split_flag = True if (len(self.player_card) == 2 and self.player_card[0][0] == self.player_card[1][0]) else False
        self.natural_flag = True if (len(self.player_card) == 2 and self.calculate_card_value(False,self.player_card) == 21) else False
        return self.state_status()

    def state_status(self):
        player_card_value = self.calculate_card_value(False,self.player_card)
        dealer_first_card = self.dealer_card[0][0]
        self.split_flag = True if (len(self.player_card) == 2 and self.player_card[0][0] == self.player_card[1][0]) else False
        self.natural_flag = True if (len(self.player_card) == 2 and self.calculate_card_value(False,self.player_card) == 21) else False
        return player_card_value,dealer_first_card,self.has_ace,self.hand,self.split_flag,self.natural_flag
    
    def contains_ace(self,player_card) : 
        for card , suit in player_card :
            if card.casefold() == ACE.casefold() :
                return True
        return False

    def step(self,q_action,rule_6_to_5,rule_no_dd_hard_11) :
        player_card_numbers = []
        dealer_card_numbers = []
        for p_card in self.player_card :
            player_card_numbers.append(p_card[0]) 
            
        for d_card in self.dealer_card :
            dealer_card_numbers.append(d_card[0]) 
            
        if q_action == SPLIT :
            if self.split_flag :
                self.split_pairs(dealer_card_numbers[0],rule_no_dd_hard_11,rule_6_to_5)
            else:
                self.reward = INVALID_ACTION_REWARD
                self.end_game = True
            return self.state_status(), self.reward, self.end_game
    
        elif q_action == DOUBLE_DOWN :
            action,double_down_action = self.double_down(self.player_card)
            self.reward+=VALID_ACTION_REWARD
            self.general_rule(action,double_down_action,rule_6_to_5)

        elif q_action == HIT:
            action = self.hit_or_stand(dealer_card_numbers[0], self.calculate_card_value(False, self.player_card))
            if q_action == action :
                self.reward += VALID_ACTION_REWARD
                self.general_rule(action, None,rule_6_to_5)
            else:
                self.reward = INVALID_ACTION_REWARD
                self.end_game = True
                return self.state_status(), self.reward, self.end_game
            
        elif q_action == STAND:
            action = self.hit_or_stand(dealer_card_numbers[0], self.calculate_card_value(False, self.player_card))
            if q_action == action :
                self.reward += VALID_ACTION_REWARD
                self.general_rule(action, None,rule_6_to_5)
            else:
                self.reward = INVALID_ACTION_REWARD
                self.end_game = True
                return self.state_status(), self.reward, self.end_game
            
        return self.state_status(),self.reward,self.end_game
        
    def general_rule(self,action,double_down_action,rule_6_to_5) :
        state_status, self.reward, end_game = self.check_for_blackjack(rule_6_to_5)
        if end_game :
            return state_status,self.reward, end_game
        # Hit / Stand
        if action.lower() == HIT :
            self.player_card.append(self.get_card())
            player_card_value = self.calculate_card_value(False,self.player_card)
            if(player_card_value > 21) :
                self.end_game = True
                self.reward = LOSE_REWARD
                return self.state_status(),self.reward,self.end_game
            else : 
                self.reward = 0
        elif action.lower() == STAND :
            #End of players turn, begin dealers turn
            self.end_game = True
            dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            while (dealer_card_value < 17 ) :
                self.dealer_card.append(self.get_card())
                dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            
            self.reward = self.winner_or_loser(double_down_action)     
        return self.state_status(),self.reward,self.end_game 
    
    
    def winner_or_loser(self,double_down_action) : 
        player_card_value = self.calculate_card_value(False,self.player_card)
        dealer_card_value = self.calculate_card_value(True,self.dealer_card)
        if double_down_action == DOUBLE_DOWN :
            if player_card_value  > 21 :
                return DOUBLE_DOWN_LOSE_REWARD #player busted
            elif dealer_card_value > 21 :
                return DOUBLE_DOWN_WIN_REWARD #Player wins dealer busted
            elif player_card_value > dealer_card_value :
                return DOUBLE_DOWN_WIN_REWARD # Player wins
            elif player_card_value < dealer_card_value : 
                return DOUBLE_DOWN_LOSE_REWARD #Player lost dealer won
            else : 
                return DRAW_REWARD #its draw
        else :
            if player_card_value  > 21 :
                return LOSE_REWARD #player busted
            elif dealer_card_value > 21 :
                return WIN_REWARD #Player wins dealer busted
            elif player_card_value > dealer_card_value :
                return WIN_REWARD # Player wins
            elif player_card_value < dealer_card_value : 
                return LOSE_REWARD #Player lost dealer won
            else : 
                return DRAW_REWARD #its draw
        
    def check_for_blackjack(self,rule_6_to_5) :
        player_card_numbers = []
        dealer_card_numbers = []
        for p_card in self.player_card :
            player_card_numbers.append(p_card[0]) 
            
        for d_card in self.dealer_card :
            dealer_card_numbers.append(d_card[0]) 
            
        self.end_game = False
        if len(player_card_numbers) == 2 and len(dealer_card_numbers) == 2 :
            player_card_value = self.calculate_card_value(False,self.player_card)
            dealer_card_value = self.calculate_card_value(True,self.dealer_card)
            if player_card_value  == 21 and dealer_card_value == 21:
                self.end_game = True
                self.reward = DRAW_REWARD
            if player_card_value == 21 :
                self.end_game = True
                if rule_6_to_5 :
                    self.reward = WIN_BLACKJACK_REWARD_6_TO_5  #Rule variation Apply 6 to 5 rule for blackjack instead of 3 to 2
                else :
                    self.reward = WIN_BLACKJACK_REWARD
            
        return self.state_status(),self.reward,self.end_game         
    
    #when same numbers occur twice split
    def choose_splitting_pairs(self,player_card_numbers,dealer_face_up_card):
        split = False
        if len(player_card_numbers) == 2:
            if player_card_numbers[0] == player_card_numbers [1] :
                #always split
                if player_card_numbers[0] in [ACE,EIGHT] :
                    split = True
                
                #never split
                if player_card_numbers[0] in [FIVE,TEN,JACK,QUEEN,KING]:
                    split = False
                
                #split based on dealer up card
                #if dealer face up card is b/w 2-7 and player has 2s or 3s or 7s
                if (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in TWO) or (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in THREE) or (dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN] and player_card_numbers[0] in SEVEN):
                    split = True
                
                #if dealer face up card is b/w 5-6 and player has 4s
                if dealer_face_up_card in [FIVE,SIX] and player_card_numbers[0] in FOUR :
                    split = True
                
                #if dealer face up card is b/w 2-6 and player has 6s
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX] and player_card_numbers[0] in SIX :
                    split = True
                
                #if dealer face up card is b/w 2-6 and player has 6s
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,EIGHT,NINE] and player_card_numbers[0] in NINE :
                    split = True
        return split
    
    #conditions for double down
    def choose_double_down(self,player_card_numbers,dealer_face_up_card,player_card_value,rule_no_dd_hard_11) :
        double_down = False
       
        if len(player_card_numbers) == 2 :
            if self.hand == HARD_HAND :
                #gets 11 always double down
                if player_card_value == 11 :
                    if rule_no_dd_hard_11 :
                        double_down = False  #Rule variation do not double down when hard 11
                    else :
                        double_down = True
                #if dealer face up card is b/w 2-9 and player has hard 10
                if dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT,NINE] and player_card_value == 10 :
                    double_down = True
                #if dealer face up card is b/w 3-6 and player has hard 9
                if dealer_face_up_card in [THREE,FOUR,FIVE,SIX] and player_card_value == 8 :
                    double_down = True
            
            if self.hand == SOFT_HAND :
                #if dealer face up card is b/w 3-6 and player has soft 13 - 18
                if player_card_value in range (13,19) and dealer_face_up_card in [THREE,FOUR,FIVE,SIX]:
                    double_down = True
                #if dealer face up card is b/w 6 and player has soft 19
                if player_card_value == 19 and dealer_face_up_card in [SIX]:
                    double_down = True
         
        return double_down
                       
    def hit_or_stand(self,dealer_face_up_card,player_card_value) :
        action = ''
        if self.hand == HARD_HAND :
            #if player has hard <=8
            if player_card_value <= 11 :
                action = HIT
                
            #if dealer face up card is 2-3 or 7-A and player has hard 12 else stand
            if player_card_value == 12 :
                if dealer_face_up_card in [TWO,THREE,SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                else : 
                    action = STAND 
        
            #if dealer face up card is 7-A and player has hard 13-16 else stand
            if player_card_value in range (13,17) :
                if dealer_face_up_card in [SEVEN,EIGHT,NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                else : 
                    action = STAND
                    
            #if  player has hard >= 17 else stand
            if player_card_value >= 17 :
                action = STAND
        
        if self.hand == SOFT_HAND :
            
            #if dealer face up card is 2-4 or 7-A and player has soft 13-14
            if player_card_value <= 17 :
                action = HIT

            #if dealer face up card is 9-A and player has soft 18 else stand dealers face up card is 2 or 7,8
            if player_card_value == 18 :
                if dealer_face_up_card in [NINE,TEN,JACK,QUEEN,KING,ACE] :
                    action = HIT
                elif dealer_face_up_card in [TWO,THREE,FOUR,FIVE,SIX,SEVEN,EIGHT] : 
                    action = STAND
            
            #if dealer face up card is not 6 and player has soft 19
            if player_card_value >= 19 :
                action = STAND
        
        return action
    
    def split_pairs(self,dealer_face_up_card,rule_no_dd_hard_11,rule_6_to_5):
        rewards = []
        player_new_card_1 = self.get_card()
        player_new_card_2 = self.get_card()
        player_hand_1 = [self.player_card[0], player_new_card_1]
        player_hand_2 = [self.player_card[1], player_new_card_2]
        player_hands = [player_hand_1, player_hand_2]
        self.player_card.append(player_new_card_1)
        self.player_card.append(player_new_card_2)
       
        for hand in player_hands:
            hand_card_numbers = []
            self.player_card = hand  # Set current hand to be played
            self.has_ace = self.contains_ace(hand)
            
            for p_card in hand :
                hand_card_numbers.append(p_card[0]) 
            
            double_down_flag = self.choose_double_down(hand_card_numbers,dealer_face_up_card,self.calculate_card_value(False,hand),rule_no_dd_hard_11)
            if double_down_flag :
                action,double_down_action = self.double_down(hand)
                state_status,self.reward,self.end_game = self.general_rule(action,double_down_action,rule_6_to_5)
                rewards.append(self.reward)
            else : 
                action = self.hit_or_stand(dealer_face_up_card,self.calculate_card_value(False,hand))
                state_status,self.reward,self.end_game = self.general_rule(action,None,rule_6_to_5)
                rewards.append(self.reward)
        
        # Determine final rewards based on the outcome of both hands
        if all(reward > 0 for reward in rewards):
            # Both hands win
            self.reward = sum(rewards)  # Add rewards for both winning hands
        elif all(reward < 0 for reward in rewards):
            # Both hands lose
            self.reward = sum(rewards)  # Sum of negative rewards is negative
        else:
            # One hand wins and one hand loses
            self.reward = sum(rewards)  # Net reward
        
        self.reward+=VALID_ACTION_REWARD
        return self.state_status(),self.reward,self.end_game 
        
    def double_down(self,hand) :
        hand.append(self.get_card())
        self.end_game = True
        action = STAND
        return action,DOUBLE_DOWN

# %%
class BlackjackAgent:
    def __init__(self, alpha, gamma, epsilon, epsilon_decay, final_epsilon):
        self.actions = ACTIONS
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma
        self.epsilon_decay = epsilon_decay
        self.final_epsilon = final_epsilon
        self.q_table = {}

    def select_action(self, current_state):
        if current_state not in self.q_table:
            self.q_table[current_state] = np.zeros(len(self.actions)) 
        #Exploration based on epsilon values
        if np.random.random() < self.epsilon:
            action = random.choice(self.actions)
        else:
        #Exploitation take highest value from Q-table
            q_values = self.q_table[current_state]
            action = self.actions[np.argmax(q_values)]
        return action

    def update_q_table(self, current_state, action, reward, next_state):
        #update Q-table
        if current_state not in self.q_table:
            self.q_table[current_state] = np.zeros(len(self.actions))
        if next_state not in self.q_table:
            self.q_table[next_state] = np.zeros(len(self.actions))
        index_of_action = self.actions.index(action)
        known_q_value = self.q_table[current_state][index_of_action]
        #calculate the likelihood using bellman equation
        predicted_q_value = reward + self.gamma * np.max(self.q_table[next_state])
        self.q_table[current_state][index_of_action] += self.alpha * (predicted_q_value - known_q_value)

    def decay_epsilon(self):
        self.epsilon = max(self.final_epsilon, self.epsilon - self.epsilon_decay)

# %%
def train_blackjack(alpha, gamma, epsilon, num_episodes, epsilon_decay, final_epsilon,rule_6_to_5, rule_no_dd_hard_11):
    play_game = Blackjack_Q()
    blackjack_agent = BlackjackAgent(alpha, gamma, epsilon, epsilon_decay, final_epsilon)
    rewards = []
    average_rewards = []
    epsilons = []
    for episode in range(num_episodes):
        current_state = play_game.state_status()
        end_game = False
        total_reward = 0
        while not end_game:
            current_action = blackjack_agent.select_action(current_state)
            next_state, reward, end_game = play_game.step(current_action,rule_6_to_5, rule_no_dd_hard_11)
            blackjack_agent.update_q_table(current_state, current_action, reward, next_state)
            current_state = next_state
            total_reward += reward
        
        play_game.reset()
        rewards.append(total_reward)
        epsilons.append(blackjack_agent.epsilon)
        
        if (episode + 1) % 1000 == 0:
            average_reward = sum(rewards[-1000:]) / 1000
            average_rewards.append(average_reward)
            print(f"Episode {episode + 1}/{num_episodes}, Average Reward: {average_reward}")

        blackjack_agent.decay_epsilon()

    return blackjack_agent, play_game, rewards,epsilons,average_rewards

# %%
def plot_epsilon_decay(epsilons, num_episodes):   
    # Plotting epsilon decay over episodes
    plt.figure(figsize=(4, 3))
    plt.plot(np.arange(1, num_episodes + 1), epsilons, label='Epsilon Decay')
    plt.title('Epsilon Decay over Episodes')
    plt.xlabel('Episode')
    plt.ylabel('Epsilon')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Training Parameters
alpha = 0.01  # learning rate
gamma = 0.8  # discount factor
epsilon = 0.95  # initial epsilon for exploration
num_episodes = 1000000
final_epsilon = 0.3
epsilon_decay = (epsilon - final_epsilon) / num_episodes

trained_agent, blackjack_env,rewards,epsilons,average_rewards = train_blackjack(alpha, gamma, epsilon, num_episodes, epsilon_decay, final_epsilon,rule_6_to_5=False, rule_no_dd_hard_11=False)
# Out:
# Episode 1000/1000000, Average Reward: -1.739
# Episode 2000/1000000, Average Reward: -1.597
# Episode 3000/1000000, Average Reward: -1.672
# Episode 4000/1000000, Average Reward: -1.611
# Episode 5000/1000000, Average Reward: -1.59
# Episode 6000/1000000, Average Reward: -1.619
# Episode 7000/1000000, Average Reward: -1.674
# Episode 8000/1000000, Average Reward: -1.573
# Episode 9000/1000000, Average Reward: -1.668
# Episode 10000/1000000, Average Reward: -1.518
# Episode 11000/1000000, Average Reward: -1.58
# Episode 12000/1000000, Average Reward: -1.557
# Episode 13000/1000000, Average Reward: -1.539
# Episode 14000/1000000, Average Reward: -1.642
# Episode 15000/1000000, Average Reward: -1.627
# Episode 16000/1000000, Average Reward: -1.576
# Episode 17000/1000000, Average Reward: -1.73
# Episode 18000/1000000, Average Reward: -1.583
# Episode 19000/1000000, Average Reward: -1.597
# Episode 20000/1000000, Average Reward: -1.634
# Episode 21000/1000000, Average Reward: -1.637
# Episode 22000/1000000, Average Reward: -1.685
# Episode 23000/1000000, Average Reward: -1.559
# Episode 24000/1000000, Average Reward: -1.549
# Episode 25000/1000000, Average Reward: -1.519
# Episode 26000/1000000, Average Reward: -1.557
# Episode 27000/1000000, Average Reward: -1.648
# Episode 28000/1000000, Average Reward: -1.608
# Episode 29000/1000000, Average Reward: -1.53
# Episode 30000/1000000, Average Reward: -1.575
# Episode 31000/1000000, Average Reward: -1.631
# Episode 32000/1000000, Average Reward: -1.495
# Episode 33000/1000000, Average Reward: -1.584
# Episode 34000/1000000, Average Reward: -1.56
# Episode 35000/1000000, Average Reward: -1.444
# Episode 36000/1000000, Average Reward: -1.751
# Episode 37000/1000000, Average Reward: -1.506
# Episode 38000/1000000, Average Reward: -1.653
# Episode 39000/1000000, Average Reward: -1.531
# Episode 40000/1000000, Average Reward: -1.431
# Episode 41000/1000000, Average Reward: -1.559
# Episode 42000/1000000, Average Reward: -1.562
# Episode 43000/1000000, Average Reward: -1.513
# Episode 44000/1000000, Average Reward: -1.451
# Episode 45000/1000000, Average Reward: -1.578
# Episode 46000/1000000, Average Reward: -1.556
# Episode 47000/1000000, Average Reward: -1.467
# Episode 48000/1000000, Average Reward: -1.49
# Episode 49000/1000000, Average Reward: -1.51
# Episode 50000/1000000, Average Reward: -1.441
# Episode 51000/1000000, Average Reward: -1.371
# Episode 52000/1000000, Average Reward: -1.619
# Episode 53000/1000000, Average Reward: -1.385
# Episode 54000/1000000, Average Reward: -1.557
# Episode 55000/1000000, Average Reward: -1.48
# Episode 56000/1000000, Average Reward: -1.467
# Episode 57000/1000000, Average Reward: -1.571
# Episode 58000/1000000, Average Reward: -1.63
# Episode 59000/1000000, Average Reward: -1.592
# Episode 60000/1000000, Average Reward: -1.49
# Episode 61000/1000000, Average Reward: -1.571
# Episode 62000/1000000, Average Reward: -1.58
# Episode 63000/1000000, Average Reward: -1.426
# Episode 64000/1000000, Average Reward: -1.533
# Episode 65000/1000000, Average Reward: -1.609
# Episode 66000/1000000, Average Reward: -1.512
# Episode 67000/1000000, Average Reward: -1.578
# Episode 68000/1000000, Average Reward: -1.544
# Episode 69000/1000000, Average Reward: -1.458
# Episode 70000/1000000, Average Reward: -1.452
# Episode 71000/1000000, Average Reward: -1.49
# Episode 72000/1000000, Average Reward: -1.518
# Episode 73000/1000000, Average Reward: -1.423
# Episode 74000/1000000, Average Reward: -1.519
# Episode 75000/1000000, Average Reward: -1.555
# Episode 76000/1000000, Average Reward: -1.541
# Episode 77000/1000000, Average Reward: -1.582
# Episode 78000/1000000, Average Reward: -1.598
# Episode 79000/1000000, Average Reward: -1.46
# Episode 80000/1000000, Average Reward: -1.548
# Episode 81000/1000000, Average Reward: -1.49
# Episode 82000/1000000, Average Reward: -1.45
# Episode 83000/1000000, Average Reward: -1.54
# Episode 84000/1000000, Average Reward: -1.381
# Episode 85000/1000000, Average Reward: -1.528
# Episode 86000/1000000, Average Reward: -1.571
# Episode 87000/1000000, Average Reward: -1.562
# Episode 88000/1000000, Average Reward: -1.387
# Episode 89000/1000000, Average Reward: -1.331
# Episode 90000/1000000, Average Reward: -1.48
# Episode 91000/1000000, Average Reward: -1.383
# Episode 92000/1000000, Average Reward: -1.524
# Episode 93000/1000000, Average Reward: -1.442
# Episode 94000/1000000, Average Reward: -1.385
# Episode 95000/1000000, Average Reward: -1.519
# Episode 96000/1000000, Average Reward: -1.476
# Episode 97000/1000000, Average Reward: -1.457
# Episode 98000/1000000, Average Reward: -1.445
# Episode 99000/1000000, Average Reward: -1.518
# Episode 100000/1000000, Average Reward: -1.486
# Episode 101000/1000000, Average Reward: -1.47
# Episode 102000/1000000, Average Reward: -1.461
# Episode 103000/1000000, Average Reward: -1.412
# Episode 104000/1000000, Average Reward: -1.423
# Episode 105000/1000000, Average Reward: -1.432
# Episode 106000/1000000, Average Reward: -1.507
# Episode 107000/1000000, Average Reward: -1.299
# Episode 108000/1000000, Average Reward: -1.48
# Episode 109000/1000000, Average Reward: -1.386
# Episode 110000/1000000, Average Reward: -1.404
# Episode 111000/1000000, Average Reward: -1.551
# Episode 112000/1000000, Average Reward: -1.364
# Episode 113000/1000000, Average Reward: -1.442
# Episode 114000/1000000, Average Reward: -1.493
# Episode 115000/1000000, Average Reward: -1.403
# Episode 116000/1000000, Average Reward: -1.497
# Episode 117000/1000000, Average Reward: -1.387
# Episode 118000/1000000, Average Reward: -1.382
# Episode 119000/1000000, Average Reward: -1.428
# Episode 120000/1000000, Average Reward: -1.291
# Episode 121000/1000000, Average Reward: -1.488
# Episode 122000/1000000, Average Reward: -1.441
# Episode 123000/1000000, Average Reward: -1.384
# Episode 124000/1000000, Average Reward: -1.465
# Episode 125000/1000000, Average Reward: -1.404
# Episode 126000/1000000, Average Reward: -1.44
# Episode 127000/1000000, Average Reward: -1.449
# Episode 128000/1000000, Average Reward: -1.438
# Episode 129000/1000000, Average Reward: -1.406
# Episode 130000/1000000, Average Reward: -1.509
# Episode 131000/1000000, Average Reward: -1.356
# Episode 132000/1000000, Average Reward: -1.519
# Episode 133000/1000000, Average Reward: -1.433
# Episode 134000/1000000, Average Reward: -1.384
# Episode 135000/1000000, Average Reward: -1.341
# Episode 136000/1000000, Average Reward: -1.455
# Episode 137000/1000000, Average Reward: -1.343
# Episode 138000/1000000, Average Reward: -1.329
# Episode 139000/1000000, Average Reward: -1.461
# Episode 140000/1000000, Average Reward: -1.416
# Episode 141000/1000000, Average Reward: -1.274
# Episode 142000/1000000, Average Reward: -1.498
# Episode 143000/1000000, Average Reward: -1.37
# Episode 144000/1000000, Average Reward: -1.241
# Episode 145000/1000000, Average Reward: -1.484
# Episode 146000/1000000, Average Reward: -1.344
# Episode 147000/1000000, Average Reward: -1.38
# Episode 148000/1000000, Average Reward: -1.425
# Episode 149000/1000000, Average Reward: -1.326
# Episode 150000/1000000, Average Reward: -1.396
# Episode 151000/1000000, Average Reward: -1.327
# Episode 152000/1000000, Average Reward: -1.28
# Episode 153000/1000000, Average Reward: -1.433
# Episode 154000/1000000, Average Reward: -1.378
# Episode 155000/1000000, Average Reward: -1.378
# Episode 156000/1000000, Average Reward: -1.399
# Episode 157000/1000000, Average Reward: -1.391
# Episode 158000/1000000, Average Reward: -1.455
# Episode 159000/1000000, Average Reward: -1.441
# Episode 160000/1000000, Average Reward: -1.262
# Episode 161000/1000000, Average Reward: -1.506
# Episode 162000/1000000, Average Reward: -1.309
# Episode 163000/1000000, Average Reward: -1.426
# Episode 164000/1000000, Average Reward: -1.358
# Episode 165000/1000000, Average Reward: -1.27
# Episode 166000/1000000, Average Reward: -1.479
# Episode 167000/1000000, Average Reward: -1.31
# Episode 168000/1000000, Average Reward: -1.439
# Episode 169000/1000000, Average Reward: -1.33
# Episode 170000/1000000, Average Reward: -1.435
# Episode 171000/1000000, Average Reward: -1.39
# Episode 172000/1000000, Average Reward: -1.348
# Episode 173000/1000000, Average Reward: -1.395
# Episode 174000/1000000, Average Reward: -1.308
# Episode 175000/1000000, Average Reward: -1.582
# Episode 176000/1000000, Average Reward: -1.311
# Episode 177000/1000000, Average Reward: -1.21
# Episode 178000/1000000, Average Reward: -1.374
# Episode 179000/1000000, Average Reward: -1.46
# Episode 180000/1000000, Average Reward: -1.459
# Episode 181000/1000000, Average Reward: -1.333
# Episode 182000/1000000, Average Reward: -1.329
# Episode 183000/1000000, Average Reward: -1.362
# Episode 184000/1000000, Average Reward: -1.356
# Episode 185000/1000000, Average Reward: -1.276
# Episode 186000/1000000, Average Reward: -1.393
# Episode 187000/1000000, Average Reward: -1.398
# Episode 188000/1000000, Average Reward: -1.462
# Episode 189000/1000000, Average Reward: -1.464
# Episode 190000/1000000, Average Reward: -1.377
# Episode 191000/1000000, Average Reward: -1.398
# Episode 192000/1000000, Average Reward: -1.186
# Episode 193000/1000000, Average Reward: -1.412
# Episode 194000/1000000, Average Reward: -1.331
# Episode 195000/1000000, Average Reward: -1.397
# Episode 196000/1000000, Average Reward: -1.3
# Episode 197000/1000000, Average Reward: -1.349
# Episode 198000/1000000, Average Reward: -1.406
# Episode 199000/1000000, Average Reward: -1.358
# Episode 200000/1000000, Average Reward: -1.437
# Episode 201000/1000000, Average Reward: -1.334
# Episode 202000/1000000, Average Reward: -1.364
# Episode 203000/1000000, Average Reward: -1.329
# Episode 204000/1000000, Average Reward: -1.403
# Episode 205000/1000000, Average Reward: -1.332
# Episode 206000/1000000, Average Reward: -1.221
# Episode 207000/1000000, Average Reward: -1.296
# Episode 208000/1000000, Average Reward: -1.44
# Episode 209000/1000000, Average Reward: -1.276
# Episode 210000/1000000, Average Reward: -1.379
# Episode 211000/1000000, Average Reward: -1.347
# Episode 212000/1000000, Average Reward: -1.356
# Episode 213000/1000000, Average Reward: -1.423
# Episode 214000/1000000, Average Reward: -1.409
# Episode 215000/1000000, Average Reward: -1.296
# Episode 216000/1000000, Average Reward: -1.355
# Episode 217000/1000000, Average Reward: -1.359
# Episode 218000/1000000, Average Reward: -1.414
# Episode 219000/1000000, Average Reward: -1.268
# Episode 220000/1000000, Average Reward: -1.419
# Episode 221000/1000000, Average Reward: -1.243
# Episode 222000/1000000, Average Reward: -1.531
# Episode 223000/1000000, Average Reward: -1.462
# Episode 224000/1000000, Average Reward: -1.425
# Episode 225000/1000000, Average Reward: -1.54
# Episode 226000/1000000, Average Reward: -1.444
# Episode 227000/1000000, Average Reward: -1.33
# Episode 228000/1000000, Average Reward: -1.072
# Episode 229000/1000000, Average Reward: -1.278
# Episode 230000/1000000, Average Reward: -1.266
# Episode 231000/1000000, Average Reward: -1.364
# Episode 232000/1000000, Average Reward: -1.418
# Episode 233000/1000000, Average Reward: -1.311
# Episode 234000/1000000, Average Reward: -1.314
# Episode 235000/1000000, Average Reward: -1.384
# Episode 236000/1000000, Average Reward: -1.337
# Episode 237000/1000000, Average Reward: -1.299
# Episode 238000/1000000, Average Reward: -1.187
# Episode 239000/1000000, Average Reward: -1.298
# Episode 240000/1000000, Average Reward: -1.36
# Episode 241000/1000000, Average Reward: -1.32
# Episode 242000/1000000, Average Reward: -1.14
# Episode 243000/1000000, Average Reward: -1.282
# Episode 244000/1000000, Average Reward: -1.218
# Episode 245000/1000000, Average Reward: -1.196
# Episode 246000/1000000, Average Reward: -1.266
# Episode 247000/1000000, Average Reward: -1.414
# Episode 248000/1000000, Average Reward: -1.191
# Episode 249000/1000000, Average Reward: -1.181
# Episode 250000/1000000, Average Reward: -1.224
# Episode 251000/1000000, Average Reward: -1.34
# Episode 252000/1000000, Average Reward: -1.423
# Episode 253000/1000000, Average Reward: -1.347
# Episode 254000/1000000, Average Reward: -1.361
# Episode 255000/1000000, Average Reward: -1.26
# Episode 256000/1000000, Average Reward: -1.417
# Episode 257000/1000000, Average Reward: -1.257
# Episode 258000/1000000, Average Reward: -1.26
# Episode 259000/1000000, Average Reward: -1.349
# Episode 260000/1000000, Average Reward: -1.27
# Episode 261000/1000000, Average Reward: -1.269
# Episode 262000/1000000, Average Reward: -1.18
# Episode 263000/1000000, Average Reward: -1.257
# Episode 264000/1000000, Average Reward: -1.298
# Episode 265000/1000000, Average Reward: -1.315
# Episode 266000/1000000, Average Reward: -1.329
# Episode 267000/1000000, Average Reward: -1.285
# Episode 268000/1000000, Average Reward: -1.404
# Episode 269000/1000000, Average Reward: -1.215
# Episode 270000/1000000, Average Reward: -1.219
# Episode 271000/1000000, Average Reward: -1.209
# Episode 272000/1000000, Average Reward: -1.153
# Episode 273000/1000000, Average Reward: -1.332
# Episode 274000/1000000, Average Reward: -1.298
# Episode 275000/1000000, Average Reward: -1.133
# Episode 276000/1000000, Average Reward: -1.254
# Episode 277000/1000000, Average Reward: -1.303
# Episode 278000/1000000, Average Reward: -1.357
# Episode 279000/1000000, Average Reward: -1.235
# Episode 280000/1000000, Average Reward: -1.215
# Episode 281000/1000000, Average Reward: -1.308
# Episode 282000/1000000, Average Reward: -1.316
# Episode 283000/1000000, Average Reward: -1.217
# Episode 284000/1000000, Average Reward: -1.186
# Episode 285000/1000000, Average Reward: -1.234
# Episode 286000/1000000, Average Reward: -1.25
# Episode 287000/1000000, Average Reward: -1.152
# Episode 288000/1000000, Average Reward: -1.385
# Episode 289000/1000000, Average Reward: -1.154
# Episode 290000/1000000, Average Reward: -1.254
# Episode 291000/1000000, Average Reward: -1.035
# Episode 292000/1000000, Average Reward: -1.1
# Episode 293000/1000000, Average Reward: -1.224
# Episode 294000/1000000, Average Reward: -1.141
# Episode 295000/1000000, Average Reward: -1.118
# Episode 296000/1000000, Average Reward: -1.24
# Episode 297000/1000000, Average Reward: -1.207
# Episode 298000/1000000, Average Reward: -1.106
# Episode 299000/1000000, Average Reward: -1.087
# Episode 300000/1000000, Average Reward: -1.123
# Episode 301000/1000000, Average Reward: -1.311
# Episode 302000/1000000, Average Reward: -1.16
# Episode 303000/1000000, Average Reward: -1.173
# Episode 304000/1000000, Average Reward: -1.093
# Episode 305000/1000000, Average Reward: -1.304
# Episode 306000/1000000, Average Reward: -1.28
# Episode 307000/1000000, Average Reward: -1.22
# Episode 308000/1000000, Average Reward: -1.193
# Episode 309000/1000000, Average Reward: -1.261
# Episode 310000/1000000, Average Reward: -1.172
# Episode 311000/1000000, Average Reward: -1.239
# Episode 312000/1000000, Average Reward: -1.219
# Episode 313000/1000000, Average Reward: -1.209
# Episode 314000/1000000, Average Reward: -1.109
# Episode 315000/1000000, Average Reward: -1.31
# Episode 316000/1000000, Average Reward: -1.26
# Episode 317000/1000000, Average Reward: -1.18
# Episode 318000/1000000, Average Reward: -1.151
# Episode 319000/1000000, Average Reward: -1.069
# Episode 320000/1000000, Average Reward: -1.286
# Episode 321000/1000000, Average Reward: -1.194
# Episode 322000/1000000, Average Reward: -1.165
# Episode 323000/1000000, Average Reward: -1.251
# Episode 324000/1000000, Average Reward: -1.241
# Episode 325000/1000000, Average Reward: -1.296
# Episode 326000/1000000, Average Reward: -1.385
# Episode 327000/1000000, Average Reward: -1.101
# Episode 328000/1000000, Average Reward: -1.316
# Episode 329000/1000000, Average Reward: -1.235
# Episode 330000/1000000, Average Reward: -1.276
# Episode 331000/1000000, Average Reward: -1.178
# Episode 332000/1000000, Average Reward: -1.168
# Episode 333000/1000000, Average Reward: -1.149
# Episode 334000/1000000, Average Reward: -1.068
# Episode 335000/1000000, Average Reward: -1.135
# Episode 336000/1000000, Average Reward: -1.186
# Episode 337000/1000000, Average Reward: -1.162
# Episode 338000/1000000, Average Reward: -1.224
# Episode 339000/1000000, Average Reward: -1.179
# Episode 340000/1000000, Average Reward: -1.157
# Episode 341000/1000000, Average Reward: -1.2
# Episode 342000/1000000, Average Reward: -1.186
# Episode 343000/1000000, Average Reward: -1.16
# Episode 344000/1000000, Average Reward: -1.3
# Episode 345000/1000000, Average Reward: -1.235
# Episode 346000/1000000, Average Reward: -1.251
# Episode 347000/1000000, Average Reward: -1.208
# Episode 348000/1000000, Average Reward: -1.164
# Episode 349000/1000000, Average Reward: -1.143
# Episode 350000/1000000, Average Reward: -1.049
# Episode 351000/1000000, Average Reward: -1.244
# Episode 352000/1000000, Average Reward: -1.157
# Episode 353000/1000000, Average Reward: -1.07
# Episode 354000/1000000, Average Reward: -1.171
# Episode 355000/1000000, Average Reward: -1.09
# Episode 356000/1000000, Average Reward: -1.188
# Episode 357000/1000000, Average Reward: -1.078
# Episode 358000/1000000, Average Reward: -1.043
# Episode 359000/1000000, Average Reward: -1.178
# Episode 360000/1000000, Average Reward: -1.017
# Episode 361000/1000000, Average Reward: -1.078
# Episode 362000/1000000, Average Reward: -0.962
# Episode 363000/1000000, Average Reward: -1.043
# Episode 364000/1000000, Average Reward: -1.178
# Episode 365000/1000000, Average Reward: -1.096
# Episode 366000/1000000, Average Reward: -1.225
# Episode 367000/1000000, Average Reward: -1.111
# Episode 368000/1000000, Average Reward: -1.168
# Episode 369000/1000000, Average Reward: -1.041
# Episode 370000/1000000, Average Reward: -1.109
# Episode 371000/1000000, Average Reward: -1.12
# Episode 372000/1000000, Average Reward: -1.165
# Episode 373000/1000000, Average Reward: -1.208
# Episode 374000/1000000, Average Reward: -1.153
# Episode 375000/1000000, Average Reward: -1.21
# Episode 376000/1000000, Average Reward: -1.065
# Episode 377000/1000000, Average Reward: -1.286
# Episode 378000/1000000, Average Reward: -0.926
# Episode 379000/1000000, Average Reward: -1.079
# Episode 380000/1000000, Average Reward: -1.105
# Episode 381000/1000000, Average Reward: -1.178
# Episode 382000/1000000, Average Reward: -1.074
# Episode 383000/1000000, Average Reward: -1.063
# Episode 384000/1000000, Average Reward: -1.189
# Episode 385000/1000000, Average Reward: -1.046
# Episode 386000/1000000, Average Reward: -1.328
# Episode 387000/1000000, Average Reward: -1.064
# Episode 388000/1000000, Average Reward: -1.032
# Episode 389000/1000000, Average Reward: -1.204
# Episode 390000/1000000, Average Reward: -1.106
# Episode 391000/1000000, Average Reward: -1.221
# Episode 392000/1000000, Average Reward: -0.994
# Episode 393000/1000000, Average Reward: -1.147
# Episode 394000/1000000, Average Reward: -1.17
# Episode 395000/1000000, Average Reward: -1.107
# Episode 396000/1000000, Average Reward: -1.163
# Episode 397000/1000000, Average Reward: -1.18
# Episode 398000/1000000, Average Reward: -1.043
# Episode 399000/1000000, Average Reward: -1.164
# Episode 400000/1000000, Average Reward: -1.141
# Episode 401000/1000000, Average Reward: -1.259
# Episode 402000/1000000, Average Reward: -1.062
# Episode 403000/1000000, Average Reward: -1.205
# Episode 404000/1000000, Average Reward: -1.147
# Episode 405000/1000000, Average Reward: -1.183
# Episode 406000/1000000, Average Reward: -1.093
# Episode 407000/1000000, Average Reward: -1.177
# Episode 408000/1000000, Average Reward: -1.137
# Episode 409000/1000000, Average Reward: -1.182
# Episode 410000/1000000, Average Reward: -1.084
# Episode 411000/1000000, Average Reward: -1.08
# Episode 412000/1000000, Average Reward: -1.054
# Episode 413000/1000000, Average Reward: -1.093
# Episode 414000/1000000, Average Reward: -0.945
# Episode 415000/1000000, Average Reward: -1.063
# Episode 416000/1000000, Average Reward: -1.025
# Episode 417000/1000000, Average Reward: -0.939
# Episode 418000/1000000, Average Reward: -1.149
# Episode 419000/1000000, Average Reward: -1.096
# Episode 420000/1000000, Average Reward: -1.174
# Episode 421000/1000000, Average Reward: -1.156
# Episode 422000/1000000, Average Reward: -1.189
# Episode 423000/1000000, Average Reward: -1.018
# Episode 424000/1000000, Average Reward: -1.074
# Episode 425000/1000000, Average Reward: -1.211
# Episode 426000/1000000, Average Reward: -1.032
# Episode 427000/1000000, Average Reward: -1.048
# Episode 428000/1000000, Average Reward: -1.207
# Episode 429000/1000000, Average Reward: -1.029
# Episode 430000/1000000, Average Reward: -1.031
# Episode 431000/1000000, Average Reward: -0.996
# Episode 432000/1000000, Average Reward: -0.963
# Episode 433000/1000000, Average Reward: -0.991
# Episode 434000/1000000, Average Reward: -1.044
# Episode 435000/1000000, Average Reward: -1.219
# Episode 436000/1000000, Average Reward: -1.058
# Episode 437000/1000000, Average Reward: -0.953
# Episode 438000/1000000, Average Reward: -1.043
# Episode 439000/1000000, Average Reward: -1.141
# Episode 440000/1000000, Average Reward: -0.954
# Episode 441000/1000000, Average Reward: -1.143
# Episode 442000/1000000, Average Reward: -1.179
# Episode 443000/1000000, Average Reward: -0.996
# Episode 444000/1000000, Average Reward: -1.03
# Episode 445000/1000000, Average Reward: -1.147
# Episode 446000/1000000, Average Reward: -0.987
# Episode 447000/1000000, Average Reward: -0.979
# Episode 448000/1000000, Average Reward: -1.039
# Episode 449000/1000000, Average Reward: -1.11
# Episode 450000/1000000, Average Reward: -1.012
# Episode 451000/1000000, Average Reward: -1.038
# Episode 452000/1000000, Average Reward: -1.015
# Episode 453000/1000000, Average Reward: -1.182
# Episode 454000/1000000, Average Reward: -1.041
# Episode 455000/1000000, Average Reward: -1.166
# Episode 456000/1000000, Average Reward: -1.162
# Episode 457000/1000000, Average Reward: -1.004
# Episode 458000/1000000, Average Reward: -1.141
# Episode 459000/1000000, Average Reward: -1.034
# Episode 460000/1000000, Average Reward: -1.063
# Episode 461000/1000000, Average Reward: -1.001
# Episode 462000/1000000, Average Reward: -1.119
# Episode 463000/1000000, Average Reward: -1.02
# Episode 464000/1000000, Average Reward: -1.051
# Episode 465000/1000000, Average Reward: -0.946
# Episode 466000/1000000, Average Reward: -0.92
# Episode 467000/1000000, Average Reward: -1.083
# Episode 468000/1000000, Average Reward: -1.049
# Episode 469000/1000000, Average Reward: -1.025
# Episode 470000/1000000, Average Reward: -0.984
# Episode 471000/1000000, Average Reward: -1.071
# Episode 472000/1000000, Average Reward: -0.988
# Episode 473000/1000000, Average Reward: -1.001
# Episode 474000/1000000, Average Reward: -1.077
# Episode 475000/1000000, Average Reward: -1.218
# Episode 476000/1000000, Average Reward: -0.903
# Episode 477000/1000000, Average Reward: -0.989
# Episode 478000/1000000, Average Reward: -0.921
# Episode 479000/1000000, Average Reward: -0.985
# Episode 480000/1000000, Average Reward: -1.043
# Episode 481000/1000000, Average Reward: -1.158
# Episode 482000/1000000, Average Reward: -1.023
# Episode 483000/1000000, Average Reward: -0.912
# Episode 484000/1000000, Average Reward: -1.061
# Episode 485000/1000000, Average Reward: -0.933
# Episode 486000/1000000, Average Reward: -0.989
# Episode 487000/1000000, Average Reward: -0.983
# Episode 488000/1000000, Average Reward: -0.991
# Episode 489000/1000000, Average Reward: -0.98
# Episode 490000/1000000, Average Reward: -0.902
# Episode 491000/1000000, Average Reward: -0.992
# Episode 492000/1000000, Average Reward: -0.961
# Episode 493000/1000000, Average Reward: -0.843
# Episode 494000/1000000, Average Reward: -1.002
# Episode 495000/1000000, Average Reward: -0.876
# Episode 496000/1000000, Average Reward: -0.798
# Episode 497000/1000000, Average Reward: -0.916
# Episode 498000/1000000, Average Reward: -0.868
# Episode 499000/1000000, Average Reward: -0.989
# Episode 500000/1000000, Average Reward: -0.794
# Episode 501000/1000000, Average Reward: -0.957
# Episode 502000/1000000, Average Reward: -1.1
# Episode 503000/1000000, Average Reward: -0.952
# Episode 504000/1000000, Average Reward: -0.936
# Episode 505000/1000000, Average Reward: -0.881
# Episode 506000/1000000, Average Reward: -1.027
# Episode 507000/1000000, Average Reward: -0.899
# Episode 508000/1000000, Average Reward: -0.888
# Episode 509000/1000000, Average Reward: -1.021
# Episode 510000/1000000, Average Reward: -1.068
# Episode 511000/1000000, Average Reward: -0.882
# Episode 512000/1000000, Average Reward: -0.87
# Episode 513000/1000000, Average Reward: -0.963
# Episode 514000/1000000, Average Reward: -0.998
# Episode 515000/1000000, Average Reward: -0.998
# Episode 516000/1000000, Average Reward: -0.992
# Episode 517000/1000000, Average Reward: -1.052
# Episode 518000/1000000, Average Reward: -0.874
# Episode 519000/1000000, Average Reward: -0.977
# Episode 520000/1000000, Average Reward: -0.96
# Episode 521000/1000000, Average Reward: -0.995
# Episode 522000/1000000, Average Reward: -0.808
# Episode 523000/1000000, Average Reward: -0.858
# Episode 524000/1000000, Average Reward: -0.873
# Episode 525000/1000000, Average Reward: -0.857
# Episode 526000/1000000, Average Reward: -1.003
# Episode 527000/1000000, Average Reward: -0.917
# Episode 528000/1000000, Average Reward: -0.872
# Episode 529000/1000000, Average Reward: -0.904
# Episode 530000/1000000, Average Reward: -0.926
# Episode 531000/1000000, Average Reward: -0.851
# Episode 532000/1000000, Average Reward: -1.018
# Episode 533000/1000000, Average Reward: -1.062
# Episode 534000/1000000, Average Reward: -0.921
# Episode 535000/1000000, Average Reward: -1.06
# Episode 536000/1000000, Average Reward: -1.082
# Episode 537000/1000000, Average Reward: -0.93
# Episode 538000/1000000, Average Reward: -0.826
# Episode 539000/1000000, Average Reward: -0.922
# Episode 540000/1000000, Average Reward: -0.896
# Episode 541000/1000000, Average Reward: -1.076
# Episode 542000/1000000, Average Reward: -1.091
# Episode 543000/1000000, Average Reward: -0.951
# Episode 544000/1000000, Average Reward: -0.938
# Episode 545000/1000000, Average Reward: -0.765
# Episode 546000/1000000, Average Reward: -0.903
# Episode 547000/1000000, Average Reward: -0.78
# Episode 548000/1000000, Average Reward: -0.89
# Episode 549000/1000000, Average Reward: -0.862
# Episode 550000/1000000, Average Reward: -0.959
# Episode 551000/1000000, Average Reward: -0.8
# Episode 552000/1000000, Average Reward: -0.894
# Episode 553000/1000000, Average Reward: -1.034
# Episode 554000/1000000, Average Reward: -0.885
# Episode 555000/1000000, Average Reward: -0.941
# Episode 556000/1000000, Average Reward: -0.971
# Episode 557000/1000000, Average Reward: -0.805
# Episode 558000/1000000, Average Reward: -0.948
# Episode 559000/1000000, Average Reward: -0.925
# Episode 560000/1000000, Average Reward: -0.98
# Episode 561000/1000000, Average Reward: -0.936
# Episode 562000/1000000, Average Reward: -0.893
# Episode 563000/1000000, Average Reward: -1.008
# Episode 564000/1000000, Average Reward: -0.807
# Episode 565000/1000000, Average Reward: -0.922
# Episode 566000/1000000, Average Reward: -0.776
# Episode 567000/1000000, Average Reward: -0.971
# Episode 568000/1000000, Average Reward: -0.97
# Episode 569000/1000000, Average Reward: -0.843
# Episode 570000/1000000, Average Reward: -0.836
# Episode 571000/1000000, Average Reward: -0.807
# Episode 572000/1000000, Average Reward: -0.846
# Episode 573000/1000000, Average Reward: -0.997
# Episode 574000/1000000, Average Reward: -0.909
# Episode 575000/1000000, Average Reward: -0.961
# Episode 576000/1000000, Average Reward: -0.801
# Episode 577000/1000000, Average Reward: -0.797
# Episode 578000/1000000, Average Reward: -0.937
# Episode 579000/1000000, Average Reward: -0.88
# Episode 580000/1000000, Average Reward: -0.722
# Episode 581000/1000000, Average Reward: -0.957
# Episode 582000/1000000, Average Reward: -1.026
# Episode 583000/1000000, Average Reward: -0.921
# Episode 584000/1000000, Average Reward: -0.799
# Episode 585000/1000000, Average Reward: -0.842
# Episode 586000/1000000, Average Reward: -0.824
# Episode 587000/1000000, Average Reward: -0.893
# Episode 588000/1000000, Average Reward: -0.835
# Episode 589000/1000000, Average Reward: -0.813
# Episode 590000/1000000, Average Reward: -0.73
# Episode 591000/1000000, Average Reward: -0.843
# Episode 592000/1000000, Average Reward: -0.916
# Episode 593000/1000000, Average Reward: -0.838
# Episode 594000/1000000, Average Reward: -0.907
# Episode 595000/1000000, Average Reward: -0.772
# Episode 596000/1000000, Average Reward: -0.869
# Episode 597000/1000000, Average Reward: -0.848
# Episode 598000/1000000, Average Reward: -0.924
# Episode 599000/1000000, Average Reward: -0.712
# Episode 600000/1000000, Average Reward: -0.816
# Episode 601000/1000000, Average Reward: -0.861
# Episode 602000/1000000, Average Reward: -0.75
# Episode 603000/1000000, Average Reward: -0.757
# Episode 604000/1000000, Average Reward: -0.799
# Episode 605000/1000000, Average Reward: -0.746
# Episode 606000/1000000, Average Reward: -0.877
# Episode 607000/1000000, Average Reward: -0.928
# Episode 608000/1000000, Average Reward: -0.852
# Episode 609000/1000000, Average Reward: -0.905
# Episode 610000/1000000, Average Reward: -0.703
# Episode 611000/1000000, Average Reward: -0.701
# Episode 612000/1000000, Average Reward: -0.799
# Episode 613000/1000000, Average Reward: -0.816
# Episode 614000/1000000, Average Reward: -0.756
# Episode 615000/1000000, Average Reward: -0.733
# Episode 616000/1000000, Average Reward: -0.928
# Episode 617000/1000000, Average Reward: -0.84
# Episode 618000/1000000, Average Reward: -0.596
# Episode 619000/1000000, Average Reward: -0.72
# Episode 620000/1000000, Average Reward: -0.758
# Episode 621000/1000000, Average Reward: -0.723
# Episode 622000/1000000, Average Reward: -0.759
# Episode 623000/1000000, Average Reward: -0.886
# Episode 624000/1000000, Average Reward: -0.822
# Episode 625000/1000000, Average Reward: -0.781
# Episode 626000/1000000, Average Reward: -0.795
# Episode 627000/1000000, Average Reward: -0.843
# Episode 628000/1000000, Average Reward: -0.978
# Episode 629000/1000000, Average Reward: -0.997
# Episode 630000/1000000, Average Reward: -0.693
# Episode 631000/1000000, Average Reward: -0.766
# Episode 632000/1000000, Average Reward: -0.87
# Episode 633000/1000000, Average Reward: -0.803
# Episode 634000/1000000, Average Reward: -0.783
# Episode 635000/1000000, Average Reward: -0.777
# Episode 636000/1000000, Average Reward: -0.814
# Episode 637000/1000000, Average Reward: -0.869
# Episode 638000/1000000, Average Reward: -0.689
# Episode 639000/1000000, Average Reward: -0.559
# Episode 640000/1000000, Average Reward: -0.688
# Episode 641000/1000000, Average Reward: -0.767
# Episode 642000/1000000, Average Reward: -0.667
# Episode 643000/1000000, Average Reward: -0.768
# Episode 644000/1000000, Average Reward: -0.559
# Episode 645000/1000000, Average Reward: -0.704
# Episode 646000/1000000, Average Reward: -0.616
# Episode 647000/1000000, Average Reward: -0.627
# Episode 648000/1000000, Average Reward: -0.785
# Episode 649000/1000000, Average Reward: -0.599
# Episode 650000/1000000, Average Reward: -0.845
# Episode 651000/1000000, Average Reward: -0.708
# Episode 652000/1000000, Average Reward: -0.715
# Episode 653000/1000000, Average Reward: -0.777
# Episode 654000/1000000, Average Reward: -0.674
# Episode 655000/1000000, Average Reward: -0.876
# Episode 656000/1000000, Average Reward: -0.883
# Episode 657000/1000000, Average Reward: -0.751
# Episode 658000/1000000, Average Reward: -0.623
# Episode 659000/1000000, Average Reward: -0.632
# Episode 660000/1000000, Average Reward: -0.877
# Episode 661000/1000000, Average Reward: -0.732
# Episode 662000/1000000, Average Reward: -0.826
# Episode 663000/1000000, Average Reward: -0.678
# Episode 664000/1000000, Average Reward: -0.633
# Episode 665000/1000000, Average Reward: -0.789
# Episode 666000/1000000, Average Reward: -0.729
# Episode 667000/1000000, Average Reward: -0.82
# Episode 668000/1000000, Average Reward: -0.836
# Episode 669000/1000000, Average Reward: -0.775
# Episode 670000/1000000, Average Reward: -0.843
# Episode 671000/1000000, Average Reward: -0.786
# Episode 672000/1000000, Average Reward: -0.857
# Episode 673000/1000000, Average Reward: -0.811
# Episode 674000/1000000, Average Reward: -0.529
# Episode 675000/1000000, Average Reward: -0.795
# Episode 676000/1000000, Average Reward: -0.747
# Episode 677000/1000000, Average Reward: -0.964
# Episode 678000/1000000, Average Reward: -0.645
# Episode 679000/1000000, Average Reward: -0.788
# Episode 680000/1000000, Average Reward: -0.782
# Episode 681000/1000000, Average Reward: -0.886
# Episode 682000/1000000, Average Reward: -0.652
# Episode 683000/1000000, Average Reward: -0.604
# Episode 684000/1000000, Average Reward: -0.766
# Episode 685000/1000000, Average Reward: -0.733
# Episode 686000/1000000, Average Reward: -0.787
# Episode 687000/1000000, Average Reward: -0.699
# Episode 688000/1000000, Average Reward: -0.791
# Episode 689000/1000000, Average Reward: -0.652
# Episode 690000/1000000, Average Reward: -0.636
# Episode 691000/1000000, Average Reward: -0.755
# Episode 692000/1000000, Average Reward: -0.652
# Episode 693000/1000000, Average Reward: -0.603
# Episode 694000/1000000, Average Reward: -0.782
# Episode 695000/1000000, Average Reward: -0.743
# Episode 696000/1000000, Average Reward: -0.843
# Episode 697000/1000000, Average Reward: -0.68
# Episode 698000/1000000, Average Reward: -0.685
# Episode 699000/1000000, Average Reward: -0.823
# Episode 700000/1000000, Average Reward: -0.731
# Episode 701000/1000000, Average Reward: -0.648
# Episode 702000/1000000, Average Reward: -0.549
# Episode 703000/1000000, Average Reward: -0.534
# Episode 704000/1000000, Average Reward: -0.648
# Episode 705000/1000000, Average Reward: -0.674
# Episode 706000/1000000, Average Reward: -0.674
# Episode 707000/1000000, Average Reward: -0.762
# Episode 708000/1000000, Average Reward: -0.518
# Episode 709000/1000000, Average Reward: -0.528
# Episode 710000/1000000, Average Reward: -0.653
# Episode 711000/1000000, Average Reward: -0.693
# Episode 712000/1000000, Average Reward: -0.704
# Episode 713000/1000000, Average Reward: -0.758
# Episode 714000/1000000, Average Reward: -0.64
# Episode 715000/1000000, Average Reward: -0.685
# Episode 716000/1000000, Average Reward: -0.696
# Episode 717000/1000000, Average Reward: -0.506
# Episode 718000/1000000, Average Reward: -0.692
# Episode 719000/1000000, Average Reward: -0.777
# Episode 720000/1000000, Average Reward: -0.561
# Episode 721000/1000000, Average Reward: -0.613
# Episode 722000/1000000, Average Reward: -0.708
# Episode 723000/1000000, Average Reward: -0.648
# Episode 724000/1000000, Average Reward: -0.744
# Episode 725000/1000000, Average Reward: -0.662
# Episode 726000/1000000, Average Reward: -0.796
# Episode 727000/1000000, Average Reward: -0.677
# Episode 728000/1000000, Average Reward: -0.796
# Episode 729000/1000000, Average Reward: -0.629
# Episode 730000/1000000, Average Reward: -0.764
# Episode 731000/1000000, Average Reward: -0.67
# Episode 732000/1000000, Average Reward: -0.558
# Episode 733000/1000000, Average Reward: -0.644
# Episode 734000/1000000, Average Reward: -0.571
# Episode 735000/1000000, Average Reward: -0.67
# Episode 736000/1000000, Average Reward: -0.672
# Episode 737000/1000000, Average Reward: -0.535
# Episode 738000/1000000, Average Reward: -0.621
# Episode 739000/1000000, Average Reward: -0.675
# Episode 740000/1000000, Average Reward: -0.598
# Episode 741000/1000000, Average Reward: -0.622
# Episode 742000/1000000, Average Reward: -0.79
# Episode 743000/1000000, Average Reward: -0.649
# Episode 744000/1000000, Average Reward: -0.609
# Episode 745000/1000000, Average Reward: -0.459
# Episode 746000/1000000, Average Reward: -0.709
# Episode 747000/1000000, Average Reward: -0.46
# Episode 748000/1000000, Average Reward: -0.619
# Episode 749000/1000000, Average Reward: -0.635
# Episode 750000/1000000, Average Reward: -0.598
# Episode 751000/1000000, Average Reward: -0.65
# Episode 752000/1000000, Average Reward: -0.676
# Episode 753000/1000000, Average Reward: -0.589
# Episode 754000/1000000, Average Reward: -0.624
# Episode 755000/1000000, Average Reward: -0.516
# Episode 756000/1000000, Average Reward: -0.556
# Episode 757000/1000000, Average Reward: -0.684
# Episode 758000/1000000, Average Reward: -0.629
# Episode 759000/1000000, Average Reward: -0.548
# Episode 760000/1000000, Average Reward: -0.695
# Episode 761000/1000000, Average Reward: -0.531
# Episode 762000/1000000, Average Reward: -0.613
# Episode 763000/1000000, Average Reward: -0.694
# Episode 764000/1000000, Average Reward: -0.621
# Episode 765000/1000000, Average Reward: -0.673
# Episode 766000/1000000, Average Reward: -0.506
# Episode 767000/1000000, Average Reward: -0.691
# Episode 768000/1000000, Average Reward: -0.59
# Episode 769000/1000000, Average Reward: -0.593
# Episode 770000/1000000, Average Reward: -0.596
# Episode 771000/1000000, Average Reward: -0.597
# Episode 772000/1000000, Average Reward: -0.631
# Episode 773000/1000000, Average Reward: -0.63
# Episode 774000/1000000, Average Reward: -0.613
# Episode 775000/1000000, Average Reward: -0.609
# Episode 776000/1000000, Average Reward: -0.575
# Episode 777000/1000000, Average Reward: -0.558
# Episode 778000/1000000, Average Reward: -0.584
# Episode 779000/1000000, Average Reward: -0.45
# Episode 780000/1000000, Average Reward: -0.627
# Episode 781000/1000000, Average Reward: -0.417
# Episode 782000/1000000, Average Reward: -0.618
# Episode 783000/1000000, Average Reward: -0.591
# Episode 784000/1000000, Average Reward: -0.575
# Episode 785000/1000000, Average Reward: -0.648
# Episode 786000/1000000, Average Reward: -0.514
# Episode 787000/1000000, Average Reward: -0.518
# Episode 788000/1000000, Average Reward: -0.5
# Episode 789000/1000000, Average Reward: -0.591
# Episode 790000/1000000, Average Reward: -0.596
# Episode 791000/1000000, Average Reward: -0.567
# Episode 792000/1000000, Average Reward: -0.756
# Episode 793000/1000000, Average Reward: -0.62
# Episode 794000/1000000, Average Reward: -0.63
# Episode 795000/1000000, Average Reward: -0.707
# Episode 796000/1000000, Average Reward: -0.574
# Episode 797000/1000000, Average Reward: -0.522
# Episode 798000/1000000, Average Reward: -0.441
# Episode 799000/1000000, Average Reward: -0.54
# Episode 800000/1000000, Average Reward: -0.62
# Episode 801000/1000000, Average Reward: -0.537
# Episode 802000/1000000, Average Reward: -0.556
# Episode 803000/1000000, Average Reward: -0.725
# Episode 804000/1000000, Average Reward: -0.408
# Episode 805000/1000000, Average Reward: -0.586
# Episode 806000/1000000, Average Reward: -0.709
# Episode 807000/1000000, Average Reward: -0.595
# Episode 808000/1000000, Average Reward: -0.665
# Episode 809000/1000000, Average Reward: -0.58
# Episode 810000/1000000, Average Reward: -0.648
# Episode 811000/1000000, Average Reward: -0.629
# Episode 812000/1000000, Average Reward: -0.539
# Episode 813000/1000000, Average Reward: -0.811
# Episode 814000/1000000, Average Reward: -0.53
# Episode 815000/1000000, Average Reward: -0.441
# Episode 816000/1000000, Average Reward: -0.538
# Episode 817000/1000000, Average Reward: -0.445
# Episode 818000/1000000, Average Reward: -0.477
# Episode 819000/1000000, Average Reward: -0.515
# Episode 820000/1000000, Average Reward: -0.514
# Episode 821000/1000000, Average Reward: -0.596
# Episode 822000/1000000, Average Reward: -0.533
# Episode 823000/1000000, Average Reward: -0.602
# Episode 824000/1000000, Average Reward: -0.528
# Episode 825000/1000000, Average Reward: -0.521
# Episode 826000/1000000, Average Reward: -0.546
# Episode 827000/1000000, Average Reward: -0.663
# Episode 828000/1000000, Average Reward: -0.491
# Episode 829000/1000000, Average Reward: -0.686
# Episode 830000/1000000, Average Reward: -0.427
# Episode 831000/1000000, Average Reward: -0.447
# Episode 832000/1000000, Average Reward: -0.542
# Episode 833000/1000000, Average Reward: -0.46
# Episode 834000/1000000, Average Reward: -0.459
# Episode 835000/1000000, Average Reward: -0.458
# Episode 836000/1000000, Average Reward: -0.441
# Episode 837000/1000000, Average Reward: -0.525
# Episode 838000/1000000, Average Reward: -0.403
# Episode 839000/1000000, Average Reward: -0.557
# Episode 840000/1000000, Average Reward: -0.608
# Episode 841000/1000000, Average Reward: -0.525
# Episode 842000/1000000, Average Reward: -0.623
# Episode 843000/1000000, Average Reward: -0.599
# Episode 844000/1000000, Average Reward: -0.476
# Episode 845000/1000000, Average Reward: -0.537
# Episode 846000/1000000, Average Reward: -0.533
# Episode 847000/1000000, Average Reward: -0.528
# Episode 848000/1000000, Average Reward: -0.405
# Episode 849000/1000000, Average Reward: -0.336
# Episode 850000/1000000, Average Reward: -0.348
# Episode 851000/1000000, Average Reward: -0.466
# Episode 852000/1000000, Average Reward: -0.793
# Episode 853000/1000000, Average Reward: -0.389
# Episode 854000/1000000, Average Reward: -0.555
# Episode 855000/1000000, Average Reward: -0.421
# Episode 856000/1000000, Average Reward: -0.467
# Episode 857000/1000000, Average Reward: -0.564
# Episode 858000/1000000, Average Reward: -0.424
# Episode 859000/1000000, Average Reward: -0.415
# Episode 860000/1000000, Average Reward: -0.47
# Episode 861000/1000000, Average Reward: -0.368
# Episode 862000/1000000, Average Reward: -0.572
# Episode 863000/1000000, Average Reward: -0.332
# Episode 864000/1000000, Average Reward: -0.362
# Episode 865000/1000000, Average Reward: -0.506
# Episode 866000/1000000, Average Reward: -0.605
# Episode 867000/1000000, Average Reward: -0.53
# Episode 868000/1000000, Average Reward: -0.382
# Episode 869000/1000000, Average Reward: -0.537
# Episode 870000/1000000, Average Reward: -0.407
# Episode 871000/1000000, Average Reward: -0.403
# Episode 872000/1000000, Average Reward: -0.314
# Episode 873000/1000000, Average Reward: -0.412
# Episode 874000/1000000, Average Reward: -0.408
# Episode 875000/1000000, Average Reward: -0.512
# Episode 876000/1000000, Average Reward: -0.321
# Episode 877000/1000000, Average Reward: -0.511
# Episode 878000/1000000, Average Reward: -0.429
# Episode 879000/1000000, Average Reward: -0.448
# Episode 880000/1000000, Average Reward: -0.457
# Episode 881000/1000000, Average Reward: -0.488
# Episode 882000/1000000, Average Reward: -0.615
# Episode 883000/1000000, Average Reward: -0.468
# Episode 884000/1000000, Average Reward: -0.503
# Episode 885000/1000000, Average Reward: -0.431
# Episode 886000/1000000, Average Reward: -0.4
# Episode 887000/1000000, Average Reward: -0.29
# Episode 888000/1000000, Average Reward: -0.561
# Episode 889000/1000000, Average Reward: -0.304
# Episode 890000/1000000, Average Reward: -0.606
# Episode 891000/1000000, Average Reward: -0.524
# Episode 892000/1000000, Average Reward: -0.257
# Episode 893000/1000000, Average Reward: -0.392
# Episode 894000/1000000, Average Reward: -0.365
# Episode 895000/1000000, Average Reward: -0.386
# Episode 896000/1000000, Average Reward: -0.382
# Episode 897000/1000000, Average Reward: -0.48
# Episode 898000/1000000, Average Reward: -0.335
# Episode 899000/1000000, Average Reward: -0.49
# Episode 900000/1000000, Average Reward: -0.358
# Episode 901000/1000000, Average Reward: -0.474
# Episode 902000/1000000, Average Reward: -0.384
# Episode 903000/1000000, Average Reward: -0.432
# Episode 904000/1000000, Average Reward: -0.435
# Episode 905000/1000000, Average Reward: -0.42
# Episode 906000/1000000, Average Reward: -0.566
# Episode 907000/1000000, Average Reward: -0.432
# Episode 908000/1000000, Average Reward: -0.429
# Episode 909000/1000000, Average Reward: -0.358
# Episode 910000/1000000, Average Reward: -0.422
# Episode 911000/1000000, Average Reward: -0.241
# Episode 912000/1000000, Average Reward: -0.386
# Episode 913000/1000000, Average Reward: -0.549
# Episode 914000/1000000, Average Reward: -0.257
# Episode 915000/1000000, Average Reward: -0.258
# Episode 916000/1000000, Average Reward: -0.47
# Episode 917000/1000000, Average Reward: -0.385
# Episode 918000/1000000, Average Reward: -0.237
# Episode 919000/1000000, Average Reward: -0.338
# Episode 920000/1000000, Average Reward: -0.321
# Episode 921000/1000000, Average Reward: -0.422
# Episode 922000/1000000, Average Reward: -0.415
# Episode 923000/1000000, Average Reward: -0.337
# Episode 924000/1000000, Average Reward: -0.512
# Episode 925000/1000000, Average Reward: -0.335
# Episode 926000/1000000, Average Reward: -0.415
# Episode 927000/1000000, Average Reward: -0.418
# Episode 928000/1000000, Average Reward: -0.367
# Episode 929000/1000000, Average Reward: -0.374
# Episode 930000/1000000, Average Reward: -0.332
# Episode 931000/1000000, Average Reward: -0.446
# Episode 932000/1000000, Average Reward: -0.381
# Episode 933000/1000000, Average Reward: -0.351
# Episode 934000/1000000, Average Reward: -0.197
# Episode 935000/1000000, Average Reward: -0.248
# Episode 936000/1000000, Average Reward: -0.51
# Episode 937000/1000000, Average Reward: -0.493
# Episode 938000/1000000, Average Reward: -0.309
# Episode 939000/1000000, Average Reward: -0.344
# Episode 940000/1000000, Average Reward: -0.38
# Episode 941000/1000000, Average Reward: -0.412
# Episode 942000/1000000, Average Reward: -0.408
# Episode 943000/1000000, Average Reward: -0.282
# Episode 944000/1000000, Average Reward: -0.442
# Episode 945000/1000000, Average Reward: -0.427
# Episode 946000/1000000, Average Reward: -0.457
# Episode 947000/1000000, Average Reward: -0.343
# Episode 948000/1000000, Average Reward: -0.455
# Episode 949000/1000000, Average Reward: -0.426
# Episode 950000/1000000, Average Reward: -0.287
# Episode 951000/1000000, Average Reward: -0.28
# Episode 952000/1000000, Average Reward: -0.361
# Episode 953000/1000000, Average Reward: -0.307
# Episode 954000/1000000, Average Reward: -0.331
# Episode 955000/1000000, Average Reward: -0.294
# Episode 956000/1000000, Average Reward: -0.355
# Episode 957000/1000000, Average Reward: -0.253
# Episode 958000/1000000, Average Reward: -0.304
# Episode 959000/1000000, Average Reward: -0.452
# Episode 960000/1000000, Average Reward: -0.328
# Episode 961000/1000000, Average Reward: -0.267
# Episode 962000/1000000, Average Reward: -0.456
# Episode 963000/1000000, Average Reward: -0.364
# Episode 964000/1000000, Average Reward: -0.26
# Episode 965000/1000000, Average Reward: -0.18
# Episode 966000/1000000, Average Reward: -0.14
# Episode 967000/1000000, Average Reward: -0.289
# Episode 968000/1000000, Average Reward: -0.356
# Episode 969000/1000000, Average Reward: -0.469
# Episode 970000/1000000, Average Reward: -0.213
# Episode 971000/1000000, Average Reward: -0.383
# Episode 972000/1000000, Average Reward: -0.311
# Episode 973000/1000000, Average Reward: -0.375
# Episode 974000/1000000, Average Reward: -0.42
# Episode 975000/1000000, Average Reward: -0.415
# Episode 976000/1000000, Average Reward: -0.292
# Episode 977000/1000000, Average Reward: -0.513
# Episode 978000/1000000, Average Reward: -0.289
# Episode 979000/1000000, Average Reward: -0.414
# Episode 980000/1000000, Average Reward: -0.333
# Episode 981000/1000000, Average Reward: -0.423
# Episode 982000/1000000, Average Reward: -0.246
# Episode 983000/1000000, Average Reward: -0.266
# Episode 984000/1000000, Average Reward: -0.326
# Episode 985000/1000000, Average Reward: -0.392
# Episode 986000/1000000, Average Reward: -0.288
# Episode 987000/1000000, Average Reward: -0.404
# Episode 988000/1000000, Average Reward: -0.181
# Episode 989000/1000000, Average Reward: -0.212
# Episode 990000/1000000, Average Reward: -0.289
# Episode 991000/1000000, Average Reward: -0.376
# Episode 992000/1000000, Average Reward: -0.312
# Episode 993000/1000000, Average Reward: -0.048
# Episode 994000/1000000, Average Reward: -0.275
# Episode 995000/1000000, Average Reward: -0.336
# Episode 996000/1000000, Average Reward: -0.203
# Episode 997000/1000000, Average Reward: -0.287
# Episode 998000/1000000, Average Reward: -0.25
# Episode 999000/1000000, Average Reward: -0.155
# Episode 1000000/1000000, Average Reward: -0.219

# %%
plot_epsilon_decay(epsilons, num_episodes)

# %%
def plot_rewards(average_reward):
    episodes_per_chunk = 1000
    num_chunks = len(average_reward)
    total_episodes = num_chunks * episodes_per_chunk

    plt.figure(figsize=(4, 3))
    plt.plot(np.arange(1, total_episodes + 1, episodes_per_chunk), average_reward, label='Average Reward')
    plt.title('Average Reward per 1000 Episode ')
    plt.xlabel('Episode')
    plt.ylabel('Average Reward')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_rewards(average_rewards)

# %%
def evaluate(eval_agent, blackjack_env, num_episodes, rule_6_to_5, rule_no_dd_hard_11):
    total_rewards = 0
    wins = 0
    losses = 0
    draws = 0
    episode_rewards = []
    original_epsilon = eval_agent.epsilon
    eval_agent.epsilon = 0  # Set epsilon to 0 to ensure no exploration
    
    for episode in range(num_episodes):
        current_state = blackjack_env.reset()
        end_game = False
        episode_reward = 0

        while not end_game:
            current_action = eval_agent.select_action(current_state)
            next_state, reward, end_game = blackjack_env.step(current_action, rule_6_to_5, rule_no_dd_hard_11)
            current_state = next_state
            episode_reward += reward
        
        total_rewards += episode_reward
        episode_rewards.append(episode_reward)

        if episode_reward > 0:
            wins += 1
        elif episode_reward == 0:
            draws += 1
        else:
            losses += 1

    average_reward = total_rewards / num_episodes
    win_rate = wins / num_episodes
    loss_rate = losses / num_episodes
    draw_rate = draws / num_episodes

    print(f"Average reward: {average_reward}")
    print(f"Number of wins: {wins}, Win rate: {win_rate}")
    print(f"Number of losses: {losses}, Loss rate: {loss_rate}")
    print(f"Number of draws: {draws}, Draw rate: {draw_rate}")

    eval_agent.epsilon = original_epsilon

    return eval_agent, episode_rewards, average_reward, win_rate, loss_rate, draw_rate

# %%
number_of_episodes = 100000
eval_agent, episode_rewards, average_reward, win_rate, loss_rate, draw_rate = evaluate(trained_agent, blackjack_env, number_of_episodes,False,False)
# Out:
# Average reward: 0.43749
# Number of wins: 44276, Win rate: 0.44276
# Number of losses: 47848, Loss rate: 0.47848
# Number of draws: 7876, Draw rate: 0.07876

# %%
plot_rewards(average_rewards)

# %% [markdown]
# #### Rule Variations

# %%
test_blackjack_bs(100000,False,False)
print('-----------------------------------------------')
test_blackjack_bs(100000,True,True)
# Out:
# Average  win reward : 2.12 , average loss reward : -1.08 , average draw reward: 0.53
# Wins: 43565 , win percentage: 43.56%
# Losses: 46835 , loss percentage: 46.84%
# Draws: 9600 , draw percentage: 9.60%
# -----------------------------------------------
# Average  win reward : 1.09 , average loss reward : -1.05 , average draw reward: 4.37
# Wins: 38969 , win percentage: 38.97%
# Losses: 46688 , loss percentage: 46.69%
# Draws: 14343 , draw percentage: 14.34%

# %% [markdown]
# Name : Preeti Venkataraman Hegde
#
# Matriculation Id : 5123764
#
# Email : preetivenkataraman.hegde@study.thws.de
